# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import types
import pandas as pd

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('test') \
    .getOrCreate()
# Out:
# 24/03/02 16:21:35 WARN Utils: Your hostname, Desktop-Gar resolves to a loopback address: 127.0.1.1; using 172.25.243.204 instead (on interface eth0)
# 24/03/02 16:21:35 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/02 16:21:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/03/02 16:21:42 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/03/02 16:21:42 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
green_schema = types.StructType([
    types.StructField("VendorID", types.IntegerType(), True),
    types.StructField("lpep_pickup_datetime", types.TimestampType(), True),
    types.StructField("lpep_dropoff_datetime", types.TimestampType(), True),
    types.StructField("store_and_fwd_flag", types.StringType(), True),
    types.StructField("RatecodeID", types.IntegerType(), True),
    types.StructField("PULocationID", types.IntegerType(), True),
    types.StructField("DOLocationID", types.IntegerType(), True),
    types.StructField("passenger_count", types.IntegerType(), True),
    types.StructField("trip_distance", types.DoubleType(), True),
    types.StructField("fare_amount", types.DoubleType(), True),
    types.StructField("extra", types.DoubleType(), True),
    types.StructField("mta_tax", types.DoubleType(), True),
    types.StructField("tip_amount", types.DoubleType(), True),
    types.StructField("tolls_amount", types.DoubleType(), True),
    types.StructField("ehail_fee", types.DoubleType(), True),
    types.StructField("improvement_surcharge", types.DoubleType(), True),
    types.StructField("total_amount", types.DoubleType(), True),
    types.StructField("payment_type", types.IntegerType(), True),
    types.StructField("trip_type", types.IntegerType(), True),
    types.StructField("congestion_surcharge", types.DoubleType(), True)
])

# %%
yellow_schema = types.StructType([
    types.StructField("VendorID", types.IntegerType(), True),
    types.StructField("tpep_pickup_datetime", types.TimestampType(), True),
    types.StructField("tpep_dropoff_datetime", types.TimestampType(), True),
    types.StructField("passenger_count", types.IntegerType(), True),
    types.StructField("trip_distance", types.DoubleType(), True),
    types.StructField("RatecodeID", types.IntegerType(), True),
    types.StructField("store_and_fwd_flag", types.StringType(), True),
    types.StructField("PULocationID", types.IntegerType(), True),
    types.StructField("DOLocationID", types.IntegerType(), True),
    types.StructField("payment_type", types.IntegerType(), True),
    types.StructField("fare_amount", types.DoubleType(), True),
    types.StructField("extra", types.DoubleType(), True),
    types.StructField("mta_tax", types.DoubleType(), True),
    types.StructField("tip_amount", types.DoubleType(), True),
    types.StructField("tolls_amount", types.DoubleType(), True),
    types.StructField("improvement_surcharge", types.DoubleType(), True),
    types.StructField("total_amount", types.DoubleType(), True),
    types.StructField("congestion_surcharge", types.DoubleType(), True)
])

# %%
# Green - 2020

year = 2020

for month in range(1, 13):
    
    print(f'processing data for {year}/{month}')

    input_path = f'data/raw/green/{year}/{month:02d}/'
    output_path = f'data/pq/green/{year}/{month:02d}/'

    df_green = spark.read \
        .option("header", "true") \
        .schema(green_schema) \
        .csv(input_path)

    df_green \
        .repartition(32) \
        .write.parquet(output_path, mode='overwrite')
# Out:
# processing data for 2020/1
# 24/03/02 16:22:20 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 2, 2020-01-21T18:26:08.000+07:00, 2020-01-21T18:34:20.000+07:00, N, 1, 75, 239, 1, 1.61, 8.0, 1.0, 0.5, 3.14, 0.0, , 0.3, 15.69, 1, 1, 2.75
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 2
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-
 2, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 2
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00003-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:25 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 1, 2020-01-03T19:00:01.000+07:00, 2020-01-03T19:05:48.000+07:00, N, 1, 244, 116, 1, 1.0, 6.0, 1.0, 0.5, 1.0, 0.0, , 0.3, 8.8, 1, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 1
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00021-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 2, 2020-01-20T18:22:52.000+07:00, 2020-01-20T18:24:33.000+07:00, N, 1, 41, 152, 1, 0.4, 3.5, 1.0, 0.5, 0.0, 0.0, , 0.3, 5.3, 2, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 2
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00015-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , 2020-01-16T14:34:00.000+07:00, 2020-01-16T15:00:00.000+07:00, , , 180, 76, , 3.97, 22.25, 2.75, 0.0, 0.0, 0.0, , 0.3, 25.3, , ,
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found:
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00014-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 2, 2020-01-29T19:55:01.000+07:00, 2020-01-29T19:59:12.000+07:00, N, 1, 166, 24, 1, 0.82, 5.0, 1.0, 0.5, 1.36, 0.0, , 0.3, 8.16, 1, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 2
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00001-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 1, 2020-01-02T10:20:42.000+07:00, 2020-01-02T10:21:07.000+07:00, N, 1, 145, 145, 1, 0.0, 2.5, 0.0, 0.5, 0.0, 0.0, , 0.3, 3.3, 2, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 1
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00005-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 2, 2020-01-07T17:48:13.000+07:00, 2020-01-07T18:00:44.000+07:00, N, 1, 41, 151, 1, 1.56, 9.5, 1.0, 0.5, 2.03, 0.0, , 0.3, 13.33, 1, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 2
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00016-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 2, 2020-01-12T17:30:50.000+07:00, 2020-01-12T17:34:31.000+07:00, N, 1, 74, 74, 1, 0.34, 4.5, 0.0, 0.5, 0.0, 0.0, , 0.3, 5.3, 2, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 2
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00013-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:26 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: 2, 2020-01-27T19:33:09.000+07:00, 2020-01-27T19:40:47.000+07:00, N, 1, 134, 135, 5, 1.59, 7.5, 1.0, 0.5, 2.79, 0.0, , 0.3, 12.09, 1, 1, 0.0
#  Schema: VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge
# Expected: VendorID but found: 2
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/green/2020/01/part-00017-4de89aaa-a710-43f9-b28d-fb5a2dc538fe-c000.csv
# 24/03/02 16:22:32 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:22:35 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:22:36 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:22:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# processing data for 2020/2
# processing data for 2020/3
# processing data for 2020/4
# processing data for 2020/5
# processing data for 2020/6
# processing data for 2020/7
# processing data for 2020/8
# processing data for 2020/9
# processing data for 2020/10
# processing data for 2020/11
# processing data for 2020/12

# %%
# Yellow - 2020

year = 2020

for month in range(1, 13):
    print(f'processing data for {year}/{month}')

    input_path = f'data/raw/yellow/{year}/{month:02d}/'
    output_path = f'data/pq/yellow/{year}/{month:02d}/'

    df_yellow = spark.read \
        .option("header", "true") \
        .schema(yellow_schema) \
        .csv(input_path)

    df_yellow \
        .repartition(100) \
        .write.parquet(output_path, mode='overwrite')
# Out:
# processing data for 2020/1
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00030-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00080-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00067-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00039-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00003-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00032-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00050-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00019-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00040-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00073-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00053-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:32 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00063-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:32 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00081-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:32 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00010-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:32 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00029-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:33 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00056-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:42 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00069-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:43 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00048-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:44 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00049-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:45 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00055-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:45 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00051-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:45 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00007-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:46 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00089-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:46 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00072-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:56 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00015-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:56 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00031-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:56 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00002-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:57 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00066-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:57 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00088-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:57 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00027-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:58 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00024-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:23:58 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00062-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:07 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00005-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:07 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00058-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:07 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00006-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:08 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00060-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:09 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00026-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:09 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00036-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:10 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00065-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:11 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00016-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:22 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00046-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:22 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00013-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:23 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00021-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:23 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00035-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:23 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00012-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:23 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00018-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:23 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00025-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:24 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00061-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00052-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00095-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00038-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00034-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00001-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00084-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:32 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00044-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:32 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00057-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:40 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00054-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:40 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00023-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:40 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00037-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:40 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00017-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:40 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00042-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:40 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00074-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:41 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00033-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:41 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00004-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:49 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00000-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:49 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00011-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:49 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00008-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:49 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00094-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:50 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00083-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:50 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00047-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:50 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00090-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:51 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00087-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:58 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00014-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:58 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00070-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:59 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00059-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:59 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00076-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:24:59 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00068-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:00 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00022-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:01 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00028-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:01 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00082-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:16 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00020-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:16 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00045-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:17 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00093-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:17 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00079-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00075-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:18 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00077-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:19 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00071-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:25:20 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00078-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:27:33 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00091-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:27:47 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00064-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:27:57 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00043-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:28:06 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00092-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:28:15 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00041-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:28:23 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00086-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:28:31 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00009-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:28:42 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 20, schema size: 18
# CSV file: file:///mnt/e/projects/dezoomcamp/5_batch_processing/code/data/raw/yellow/2020/01/part-00085-0e74354d-a4f8-47cf-a2a9-85fd33ea1095-c000.csv
# 24/03/02 16:29:00 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:09 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:12 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:15 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:22 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:30 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:33 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:36 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:43 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:45 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:46 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:46 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:49 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:50 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:55 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:56 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/03/02 16:29:59 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# processing data for 2020/2
# [Stage 17:>                                                         (0 + 1) / 1]
# processing data for 2020/3
# processing data for 2020/4
# processing data for 2020/5
# processing data for 2020/6
# processing data for 2020/7
# processing data for 2020/8
# processing data for 2020/9
# processing data for 2020/10
# processing data for 2020/11
# [Stage 26:>                                                         (0 + 1) / 1]
# processing data for 2020/12

# %% [markdown]
# year = 2021
#
# for month in range(1, 13):
#     print(f'processing data for {year}/{month}')
#
#     input_path = f'data/raw/green/{year}/{month:02d}/'
#     output_path = f'data/pq/green/{year}/{month:02d}/'
#
#     df_green = spark.read \
#         .option("header", "true") \
#         .schema(green_schema) \
#         .csv(input_path)
#
#     df_green \
#         .repartition(32) \
#         .write.parquet(output_path, mode='overwrite')

# %% [markdown]
# year = 2021
#
# for month in range(1, 13):
#     print(f'processing data for {year}/{month}')
#
#     input_path = f'data/raw/yellow/{year}/{month:02d}/'
#     output_path = f'data/pq/yellow/{year}/{month:02d}/'
#
#     df_yellow = spark.read \
#         .option("header", "true") \
#         .schema(yellow_schema) \
#         .csv(input_path)
#
#     df_yellow \
#         .repartition(120) \
#         .write.parquet(output_path, mode='overwrite')
